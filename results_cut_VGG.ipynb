l_third = {'loss': [0.54575738316067401, 0.44160124754101165, 0.42736971978725757, 0.42426565502639141, 0.42141886527158245, 0.41688469702997544, 0.41511769934614368, 0.42232682708077635, 0.41117057370106841, 0.40910463375458034], 'val_loss': [0.50195405292510986, 0.44595918083190916, 0.48826989030838014, 0.51663105869293213, 0.43220335030555723, 0.43387570762634275, 0.45690466880798342, 0.48814501094818114, 0.48001123571395876, 0.50207584428787233], 'val_acc': [0.74399999999999999, 0.80100000000000005, 0.77400000000000002, 0.75, 0.79800000000000004, 0.80400000000000005, 0.78700000000000003, 0.77200000000000002, 0.77300000000000002, 0.754], 'acc': [0.73243515488783795, 0.79155124656741604, 0.79967262654243265, 0.80093175525540405, 0.80565348778645174, 0.8086753966555551, 0.80905313523042055, 0.80634600857708505, 0.81371191137235066, 0.81346008565077044]}
l_last = {'loss': [0.64976845328557464, 0.55813042651012901, 0.5488790137075531, 0.54323209797786665, 0.53552932575348788, 0.53177346828391525, 0.52759462279776304, 0.52480906880012956, 0.52264716150297741, 0.52020355995281975], 'val_loss': [0.62733252143859863, 0.58320110797882085, 0.60987434959411624, 0.56265688180923457, 0.54876986503601077, 0.61545558357238772, 0.61803436565399172, 0.5650015745162964, 0.54298848772048947, 0.52127252435684202], 'val_acc': [0.627, 0.68000000000000005, 0.64300000000000002, 0.71099999999999997, 0.73199999999999998, 0.63500000000000001, 0.63900000000000001, 0.69999999999999996, 0.73499999999999999, 0.76400000000000001], 'acc': [0.65764291112052498, 0.70423067240473669, 0.71480735332651846, 0.71864769580952015, 0.72676907582956674, 0.72494333920926723, 0.73526819440946867, 0.73816419039526682, 0.73677914884402029, 0.73784940820951905]}

# %%
def plot_nets(f, key, ):
    num_epochs = len(l_full[key])
    x = [i+1 for i in range(num_epochs)]
    g_full, = f.plot(x, l_full[key])
    g_first, = f.plot(x, l_first[key])
    g_second, = f.plot(x, l_second[key])
    g_third, = f.plot(x, l_third[key])
    g_last, = f.plot(x, l_last[key])
    f.set_title(key)
    
    f.annotate(str(round(l_full[key][num_epochs-1], 3)), xy=(x[num_epochs-1], l_full[key][num_epochs-1]))
    f.annotate(str(round(l_first[key][num_epochs-1], 3)), xy=(x[num_epochs-1], l_first[key][num_epochs-1]))
    f.annotate(str(round(l_second[key][num_epochs-1], 3)), xy=(x[num_epochs-1], l_second[key][num_epochs-1]))
    f.annotate(str(round(l_third[key][num_epochs-1], 3)), xy=(x[num_epochs-1], l_third[key][num_epochs-1]))
    f.annotate(str(round(l_last[key][num_epochs-1], 3)), xy=(x[num_epochs-1], l_last[key][num_epochs-1]))
        
    f.legend([g_full, g_first, g_second, g_third, g_last], ['VGG - 21 layers', '17 layers', '13 layers', 
                                                            '9 layers', '6 layers'], loc = 'lower left')

# %%
f, axarr = plt.subplots(2, 2, figsize = (15, 15))
plt.title('Learning results on cut VGG net')
axarr[0, 0] = plot_nets(axarr[0, 0], 'val_acc')
axarr[0, 1] = plot_nets(axarr[0, 1], 'acc')
axarr[1, 0] = plot_nets(axarr[1, 0], 'val_loss')
axarr[1, 1] = plot_nets(axarr[1, 1], 'loss')

plt.show()
